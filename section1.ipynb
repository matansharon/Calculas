# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xx=np.linspace(-2,2,100)
X,Y=np.meshgrid(xx,xx)
f=4
f2=8 
z=f*np.sin(X)*np.sin(f2*Y)
plt.contourf(X,Y,z)
plt.quiver(X,Y,np.cos(X)*np.sin(Y),np.sin(X)*np.cos(Y))
